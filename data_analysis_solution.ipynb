# %%
#import libraries:
import pandas as pd

# %% [markdown]
# ### data gathring:

# %% [markdown]
# 1. Read in the dataset and take a look at the top few rows here:

# %%
#read the csv file 
df = pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# ### data assessing:

# %% [markdown]
# b. Find the number of rows and columns in the dataset.

# %%
#general infomration ,describe,info,shape
df.shape[0]
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %%
#drop unwanted columns: 
#[cast,overview,tagline,keywords,production_companies,homepage,imdb_id]
df.drop(['cast','overview','tagline','keywords','production_companies','homepage','imdb_id'], axis=1, inplace=True)

# %%
#correct the wrong data type to a propper type
df['release_date'] = pd.to_datetime(df['release_date'])
df['budget'] = df['budget'].astype(int)
df['id'] = df['id'].astype(str)
df['popularity'] = df['popularity'].astype(float)

# %%
#to print out a spesfic time
df.release_date.dt.weekday_name #.time/ dt.hour
# Out:
# 0          Tuesday
# 1        Wednesday
# 2        Wednesday
# 3          Tuesday
# 4        Wednesday
# 5           Friday
# 6          Tuesday
# 7        Wednesday
# 8        Wednesday
# 9          Tuesday
# 10          Monday
# 11       Wednesday
# 12       Wednesday
# 13        Thursday
# 14       Wednesday
# 15          Friday
# 16        Thursday
# 17         Tuesday
# 18        Thursday
# 19       Wednesday
# 20         Tuesday
# 21          Monday
# 22       Wednesday
# 23       Wednesday
# 24          Friday
# 25        Thursday
# 26        Thursday
# 27        Saturday
# 28          Friday
# 29       Wednesday
#            ...
# 10836       Friday
# 10837       Monday
# 10838       Monday
# 10839    Wednesday
# 10840    Wednesday
# 10841     Saturday
# 10842       Friday
# 10843    Wednesday
# 10844     Saturday
# 10845       Monday
# 10846     Saturday
# 10847       Sunday
# 10848      Tuesday
# 10849     Thursday
# 10850      Tuesday
# 10851      Tuesday
# ...

# %% [markdown]
# f. How many missing values in the dataset?

# %%
#null values
df.isnull().sum()
# Out:
# id                 0
# popularity         0
# budget             0
# revenue            0
# original_title     0
# director          44
# runtime            0
# genres            23
# release_date       0
# vote_count         0
# vote_average       0
# release_year       0
# budget_adj         0
# revenue_adj        0
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                0
# popularity        0
# budget            0
# revenue           0
# original_title    0
# director          0
# runtime           0
# genres            0
# release_date      0
# vote_count        0
# vote_average      0
# release_year      0
# budget_adj        0
# revenue_adj       0
# dtype: int64

# %% [markdown]
# f. how many diplucated rows in the dataset?

# %%
#diplicated values
df.duplicated().sum()
#to print out the duplicated rows:
df[df.duplicated(keep=False)]
# Out:
#          id  popularity    budget  revenue original_title          director  \
# 2089  42194     0.59643  30000000   967000         TEKKEN  Dwight H. Little
# 2090  42194     0.59643  30000000   967000         TEKKEN  Dwight H. Little
#
#       runtime                                       genres release_date  \
# 2089       92  Crime|Drama|Action|Thriller|Science Fiction   2010-03-20
# 2090       92  Crime|Drama|Action|Thriller|Science Fiction   2010-03-20
#
#       vote_count  vote_average  release_year  budget_adj  revenue_adj
# 2089         110           5.0          2010  30000000.0     967000.0
# 2090         110           5.0          2010  30000000.0     967000.0

# %%
#drop diplicated rows
df.drop_duplicates(inplace= True)
df.duplicated().sum()
# Out:
# 0

# %%
#splitting genres column:
df['genres']=df['genres'].str.split('|', 1,expand=True)

# %%
#most genres movies:
df.genres.value_counts()
# Out:
# Drama              2447
# Comedy             2313
# Action             1587
# Horror              914
# Adventure           586
# Thriller            491
# Documentary         424
# Animation           398
# Crime               380
# Fantasy             272
# Science Fiction     212
# Romance             185
# Family              142
# Mystery             125
# Music                96
# TV Movie             74
# War                  59
# History              44
# Western              42
# Foreign               9
# Name: genres, dtype: int64

# %%
#visulaiztion: hist scatter,bar
df.genres.value_counts().plot.bar();

# %%
df.budget.plot.hist();

# %%
df.plot.scatter("budget","revenue" );

# %%
#filter/mask/query: you can do it by many methods:
#1
df2=df[df['genres']=='Action']
#2
df2=df.query('genres=="Action"')
df2
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# 10     206647    6.200282  245000000   880674609
# 13     257344    5.984995   88000000   243637091
# 14      99861    5.944927  280000000  1405035767
# 20     158852    5.462138  190000000   209035668
# 21     307081    5.337064   30000000    91709827
# 22     254128    4.907832  110000000   470490832
# 25     177677    4.566713  150000000   682330139
# 29     294254    3.968891   61000000   311256926
# 38     241554    3.237370   50000000    71561644
# 45     325348    3.023253   10000000    14333790
# 54     257088    2.614499  105000000   133718711
# 60     273481    2.487849   30000000    84025816
# 61     166424    2.487042  120000001   167977596
# 63     238713    2.404473   65000000   235666219
# ...

# %%
#grouping:
df3=df.groupby('genres')['popularity','revenue'].mean()

df3
# Out:
#                  popularity       revenue
# genres
# Action             0.837782  6.087339e+07
# Adventure          1.217868  1.247560e+08
# Animation          0.817977  7.235439e+07
# Comedy             0.538260  2.937850e+07
# Crime              0.694063  3.343632e+07
# Documentary        0.179317  2.009933e+06
# Drama              0.553444  2.520119e+07
# Family             0.739779  6.235530e+07
# Fantasy            0.865390  6.729393e+07
# Foreign            0.167124  0.000000e+00
# History            0.764636  4.436062e+07
# Horror             0.468638  1.688471e+07
# Music              0.462125  2.400642e+07
# Mystery            0.596896  2.415905e+07
# Romance            0.707231  3.809129e+07
# Science Fiction    1.082355  8.040755e+07
# TV Movie           0.245873  5.675676e+05
# Thriller           0.673381  2.648324e+07
# War                0.767041  4.590766e+07
# Western            0.690646  3.109095e+07

# %%
#export the dataframe to csv file
df.to_csv('datamovies.csv' , index=False)
